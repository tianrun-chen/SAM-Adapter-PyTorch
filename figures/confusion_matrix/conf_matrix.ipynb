# %%
from torchmetrics.classification import ConfusionMatrix
import argparse
import torch
from torchvision import transforms
from PIL import Image
from torchvision.transforms import InterpolationMode
import matplotlib.pyplot as plt 
import matplotlib
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

# %%
pred_img = Image.open('/home/kandelaki/git/SAM-Adapter-PyTorch/forward_results/pred_0.png')
gt_img = Image.open('/home/kandelaki/bt/data_20/preprocessed/256/load/masks/eval/34.png')
gt_img = transforms.Resize((1024,1024), interpolation=InterpolationMode.NEAREST)(gt_img)

input_img = Image.open('/home/kandelaki/git/SAM-Adapter-PyTorch/forward_folder/34.png')
input_img = transforms.Resize((1024,1024), interpolation=InterpolationMode.NEAREST)(input_img)

pred = torch.tensor(transforms.ToTensor()(pred_img))
gt = torch.tensor(transforms.ToTensor()(gt_img))
pred = pred > 0.5


fig, (ax1, ax2) = plt.subplots(1, 2)
# ax1.imshow(input_img)
# ax1.set_title('Input Image')
# ax1.axis('off')
# ax2.imshow(pred_img)
# ax2.set_title('Predicted Mask')

plt.savefig('pred.pgf')
# Out:
# /tmp/ipykernel_30379/2065732685.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pred = torch.tensor(transforms.ToTensor()(pred_img))
# /tmp/ipykernel_30379/2065732685.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gt = torch.tensor(transforms.ToTensor()(gt_img))
# ---------------------------------------------------------------------------
# LatexError                                Traceback (most recent call last)
# Cell In[15], line 20
#      13 fig, (ax1, ax2) = plt.subplots(1, 2)
#      14 # ax1.imshow(input_img)
#      15 # ax1.set_title('Input Image')
#      16 # ax1.axis('off')
#      17 # ax2.imshow(pred_img)
#      18 # ax2.set_title('Predicted Mask')
# ...
